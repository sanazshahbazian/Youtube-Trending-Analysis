# %%
# Dependencies
import pandas as pd
import numpy as np
import datetime as dt
import os,sys
from scipy import stats

# %%
# Store filepath in a variable
us_file = "youtube_trending_CA.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
yt_us_df = pd.read_csv(us_file)

# %%
yt_us_df.head()
# Out:
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    11/14/2017
# 1     1  0dBIkQ4Mz1M    11/14/2017
# 2     2  5qpjK5DgCt4    11/14/2017
# 3     3  d380meD0W0M    11/14/2017
# 4     4  2Vv-BfVoq4g    11/14/2017
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views      likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0   787425.0
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0   127794.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0   146035.0
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0   132239.0
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  1634130.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False

# %%
yt_us_df.shape
# Out:
# (41254, 18)

# %%
yt_us_new_DF = yt_us_df
yt_us_new_DF.head()
# Out:
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    11/14/2017
# 1     1  0dBIkQ4Mz1M    11/14/2017
# 2     2  5qpjK5DgCt4    11/14/2017
# 3     3  d380meD0W0M    11/14/2017
# 4     4  2Vv-BfVoq4g    11/14/2017
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views      likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0   787425.0
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0   127794.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0   146035.0
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0   132239.0
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  1634130.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False

# %%
# Check how many rows have null values
yt_us_new_DF.isnull().sum()
# Out:
# index                       41
# video_id                   373
# trending_date              373
# title                      373
# channel_title              373
# category_id                373
# publish_time (GMT)         373
# publish_time(CST)         7824
# tags                       373
# views                      373
# likes                      373
# dislikes                   373
# comment_count              373
# thumbnail_link             373
# country                   7824
# comments_disabled          373
# ratings_disabled           373
# video_error_or_removed     373
# dtype: int64

# %%
# Only keep rows where there is a valid video_id

yt_us_new_DF = yt_us_new_DF[yt_us_new_DF['video_id'].notna()]
yt_us_new_DF.isnull().sum()
# Out:
# index                        0
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time (GMT)           0
# publish_time(CST)         7684
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# country                   7684
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# dtype: int64

# %%
# Change data type of trending_date column

yt_us_new_DF['trending_date'] = yt_us_new_DF['trending_date'].astype('datetime64[ns]')
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views      likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0   787425.0
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0   127794.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0   146035.0
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0   132239.0
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  1634130.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False

# %%
# Create new column for last day trending video appears in dataset
yt_us_new_DF['max_date'] = yt_us_new_DF.groupby('video_id').trending_date.transform('max')
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views      likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0   787425.0
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0   127794.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0   146035.0
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0   132239.0
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  1634130.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed   max_date
# 0  Canada             False            False                  False 2017-11-17
# 1  Canada             False            False                  False 2017-11-18
# 2  Canada             False            False                  False 2017-11-17
# 3  Canada             False            False                  False 2017-11-17
# 4  Canada             False            False                  False 2017-11-15

# %%
# Create new column for first day trending video appears in dataset

yt_us_new_DF['min_date'] = yt_us_new_DF.groupby('video_id').trending_date.transform('min')
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views      likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0   787425.0
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0   127794.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0   146035.0
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0   132239.0
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  1634130.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed  \
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False
#
#     max_date   min_date
# 0 2017-11-17 2017-11-14
# 1 2017-11-18 2017-11-14
# 2 2017-11-17 2017-11-14
# 3 2017-11-17 2017-11-14
# 4 2017-11-15 2017-11-14

# %%
yt_us_new_DF.dtypes
# Out:
# index                             object
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                      float64
# publish_time (GMT)                object
# publish_time(CST)                 object
# tags                              object
# views                            float64
# likes                            float64
# dislikes                         float64
# comment_count                    float64
# thumbnail_link                    object
# country                           object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# max_date                  datetime64[ns]
# min_date                  datetime64[ns]
# dtype: object

# %%
# Create new column for how many days video appears in trending dataset

yt_us_new_DF['days_trending'] = yt_us_new_DF["max_date"] - yt_us_new_DF["min_date"]
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed  \
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False
#
#     max_date   min_date days_trending
# 0 2017-11-17 2017-11-14        3 days
# 1 2017-11-18 2017-11-14        4 days
# 2 2017-11-17 2017-11-14        3 days
# 3 2017-11-17 2017-11-14        3 days
# 4 2017-11-15 2017-11-14        1 days
#
# [5 rows x 21 columns]

# %%
# Change datatype of days_trending column to string

yt_us_new_DF['days_trending'] = yt_us_new_DF['days_trending'].astype('str')
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed  \
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False
#
#     max_date   min_date              days_trending
# 0 2017-11-17 2017-11-14  3 days 00:00:00.000000000
# 1 2017-11-18 2017-11-14  4 days 00:00:00.000000000
# 2 2017-11-17 2017-11-14  3 days 00:00:00.000000000
# 3 2017-11-17 2017-11-14  3 days 00:00:00.000000000
# 4 2017-11-15 2017-11-14  1 days 00:00:00.000000000
#
# [5 rows x 21 columns]

# %%
# Change days_trending column to integer

yt_us_new_DF['days_trending'] = yt_us_new_DF['days_trending'].str.rstrip(' days 00:00:00.000000000')
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0   43420.0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1    1688.0        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4   21082.0        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   country comments_disabled ratings_disabled video_error_or_removed  \
# 0  Canada             False            False                  False
# 1  Canada             False            False                  False
# 2  Canada             False            False                  False
# 3  Canada             False            False                  False
# 4  Canada             False            False                  False
#
#     max_date   min_date days_trending
# 0 2017-11-17 2017-11-14             3
# 1 2017-11-18 2017-11-14             4
# 2 2017-11-17 2017-11-14             3
# 3 2017-11-17 2017-11-14             3
# 4 2017-11-15 2017-11-14             1
#
# [5 rows x 21 columns]

# %%
yt_us_new_DF['days_trending'] = yt_us_new_DF['days_trending'].str.strip()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yt_us_new_DF['days_trending'].unique()
# Out:
# array(['3', '4', '1', '', '2', '212', '5', '6', '7'], dtype=object)

# %%
yt_us_new_DF.isnull().sum()
# Out:
# index                        0
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time (GMT)           0
# publish_time(CST)         7684
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# country                   7684
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# max_date                     0
# min_date                     0
# days_trending                0
# dtype: int64

# %%
yt_us_new_DF['days_trending'] = yt_us_new_DF['days_trending'].str.replace('', '0')
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yt_us_new_DF['days_trending'] = '0' + yt_us_new_DF['days_trending'].astype(str)
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yt_us_new_DF['days_trending'].unique()
# Out:
# array(['0030', '0040', '0010', '00', '0020', '00201020', '0050', '0060',
#        '0070'], dtype=object)

# %%
yt_us_new_DF['days_trending'] = yt_us_new_DF['days_trending'].astype('int') +1
yt_us_new_DF['days_trending']
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0        31
# 1        41
# 2        31
# 3        31
# 4        11
#          ..
# 41249     1
# 41250     1
# 41251    21
# 41252     1
# 41253     1
# Name: days_trending, Length: 40881, dtype: int32

# %%
# Get max views for rows that are latest date

yt_us_new_DF["max_views"] = yt_us_new_DF.query('trending_date==max_date')['views']                                           
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#    comment_count                                  thumbnail_link  country  \
# 0       125882.0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg   Canada
# 1        13030.0  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg   Canada
# 2         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg   Canada
# 3        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg   Canada
# 4        85067.0  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg   Canada
#
#   comments_disabled ratings_disabled video_error_or_removed   max_date  \
# 0             False            False                  False 2017-11-17
# 1             False            False                  False 2017-11-18
# 2             False            False                  False 2017-11-17
# 3             False            False                  False 2017-11-17
# 4             False            False                  False 2017-11-15
#
#     min_date days_trending max_views
# 0 2017-11-14            31       NaN
# 1 2017-11-14            41       NaN
# 2 2017-11-14            31       NaN
# 3 2017-11-14            31       NaN
# 4 2017-11-14            11       NaN
#
# [5 rows x 22 columns]

# %%
# Get min views for rows that are the earliest date

yt_us_new_DF["min_views"] = yt_us_new_DF.query('trending_date==min_date')['views']                                           
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#                                    thumbnail_link  country  comments_disabled  \
# 0  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg   Canada              False
# 1  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg   Canada              False
# 2  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg   Canada              False
# 3  https://i.ytimg.com/vi/d380meD0W0M/default.jpg   Canada              False
# 4  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg   Canada              False
#
#   ratings_disabled video_error_or_removed   max_date   min_date days_trending  \
# 0            False                  False 2017-11-17 2017-11-14            31
# 1            False                  False 2017-11-18 2017-11-14            41
# 2            False                  False 2017-11-17 2017-11-14            31
# 3            False                  False 2017-11-17 2017-11-14            31
# 4            False                  False 2017-11-15 2017-11-14            11
#
#   max_views   min_views
# 0       NaN  17158579.0
# 1       NaN   1014651.0
# 2       NaN   3191434.0
# 3       NaN   2095828.0
# 4       NaN  33523622.0
#
# [5 rows x 23 columns]

# %%
# Get max likes & min likes for rows that are latest and earliest date

yt_us_new_DF["max_likes"] = yt_us_new_DF.query('trending_date==max_date')['likes']
yt_us_new_DF["min_likes"] = yt_us_new_DF.query('trending_date==min_date')['likes']        
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#    comments_disabled  ratings_disabled  video_error_or_removed   max_date  \
# 0              False             False                   False 2017-11-17
# 1              False             False                   False 2017-11-18
# 2              False             False                   False 2017-11-17
# 3              False             False                   False 2017-11-17
# 4              False             False                   False 2017-11-15
#
#     min_date days_trending max_views   min_views max_likes  min_likes
# 0 2017-11-14            31       NaN  17158579.0       NaN   787425.0
# 1 2017-11-14            41       NaN   1014651.0       NaN   127794.0
# 2 2017-11-14            31       NaN   3191434.0       NaN   146035.0
# 3 2017-11-14            31       NaN   2095828.0       NaN   132239.0
# 4 2017-11-14            11       NaN  33523622.0       NaN  1634130.0
#
# [5 rows x 25 columns]

# %%
# Get max dislikes and min dislikes for rows that are latest and earliest date

yt_us_new_DF["max_dislikes"] = yt_us_new_DF.query('trending_date==max_date')['dislikes']
yt_us_new_DF["min_dislikes"] = yt_us_new_DF.query('trending_date==min_date')['dislikes']        
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#    video_error_or_removed   max_date   min_date days_trending max_views  \
# 0                   False 2017-11-17 2017-11-14            31       NaN
# 1                   False 2017-11-18 2017-11-14            41       NaN
# 2                   False 2017-11-17 2017-11-14            31       NaN
# 3                   False 2017-11-17 2017-11-14            31       NaN
# 4                   False 2017-11-15 2017-11-14            11       NaN
#
#     min_views max_likes  min_likes max_dislikes min_dislikes
# 0  17158579.0       NaN   787425.0          NaN      43420.0
# 1   1014651.0       NaN   127794.0          NaN       1688.0
# 2   3191434.0       NaN   146035.0          NaN       5339.0
# 3   2095828.0       NaN   132239.0          NaN       1989.0
# 4  33523622.0       NaN  1634130.0          NaN      21082.0
#
# [5 rows x 27 columns]

# %%
# Get max dislikes and min dislikes for rows that are latest and earliest date

yt_us_new_DF["max_comments"] = yt_us_new_DF.query('trending_date==max_date')['comment_count']
yt_us_new_DF["min_comments"] = yt_us_new_DF.query('trending_date==min_date')['comment_count']        
yt_us_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   index     video_id trending_date  \
# 0     0  n1WpP7iowLc    2017-11-14
# 1     1  0dBIkQ4Mz1M    2017-11-14
# 2     2  5qpjK5DgCt4    2017-11-14
# 3     3  d380meD0W0M    2017-11-14
# 4     4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id publish_time (GMT) publish_time(CST)  \
# 0         10.0   11/10/2017 17:00  11/10/2017 11:00
# 1         23.0   11/13/2017 17:00  11/13/2017 11:00
# 2         23.0   11/12/2017 19:05  11/12/2017 13:05
# 3         24.0   11/12/2017 18:01  11/12/2017 12:01
# 4         10.0    11/9/2017 11:04    11/9/2017 5:04
#
#                                                 tags       views  ...  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0  ...
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651.0  ...
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434.0  ...
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828.0  ...
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622.0  ...
#
#     min_date  days_trending  max_views   min_views max_likes  min_likes  \
# 0 2017-11-14             31        NaN  17158579.0       NaN   787425.0
# 1 2017-11-14             41        NaN   1014651.0       NaN   127794.0
# 2 2017-11-14             31        NaN   3191434.0       NaN   146035.0
# 3 2017-11-14             31        NaN   2095828.0       NaN   132239.0
# 4 2017-11-14             11        NaN  33523622.0       NaN  1634130.0
#
#   max_dislikes min_dislikes max_comments min_comments
# 0          NaN      43420.0          NaN     125882.0
# 1          NaN       1688.0          NaN      13030.0
# 2          NaN       5339.0          NaN       8181.0
# 3          NaN       1989.0          NaN      17518.0
# 4          NaN      21082.0          NaN      85067.0
#
# [5 rows x 29 columns]

# %%
yt_us_new_DF.dtypes
# Out:
# index                             object
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                      float64
# publish_time (GMT)                object
# publish_time(CST)                 object
# tags                              object
# views                            float64
# likes                            float64
# dislikes                         float64
# comment_count                    float64
# thumbnail_link                    object
# country                           object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# max_date                  datetime64[ns]
# min_date                  datetime64[ns]
# days_trending                      int32
# max_views                        float64
# min_views                        float64
# max_likes                        float64
# min_likes                        float64
# max_dislikes                     float64
# min_dislikes                     float64
# max_comments                     float64
# min_comments                     float64
# dtype: object

# %%
yt_us_new_DF.to_csv('CleanData_CA.csv', index=False, header=True)
