# %%
# Dependencies
import pandas as pd
import numpy as np
import datetime as dt
import os,sys
from scipy import stats

# %%
# Store filepath in a variable
gb_file = "youtube_trending_GB1.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
yt_gb_df = pd.read_csv(gb_file)

# %%
yt_gb_df.head()
# Out:
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    11/14/2017
# 1     1  3s1rvMFUweQ    11/14/2017
# 2     2  n1WpP7iowLc    11/14/2017
# 3     3  PUTEiSjKwJU    11/14/2017
# 4     4  rHwDegptbI4    11/14/2017
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id      publish_time  \
# 0                  John Lewis         26.0   11/10/2017 7:38
# 1         Saturday Night Live         24.0   11/12/2017 6:24
# 2                  EminemVEVO         10.0  11/10/2017 17:00
# 3  Salford City Football Club         17.0   11/13/2017 2:30
# 4            Cute Girl Videos         25.0   11/13/2017 1:45
#
# ...

# %%
yt_gb_df.shape
# Out:
# (39238, 18)

# %%
yt_gb_new_DF = yt_gb_df
yt_gb_new_DF.head()
# Out:
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    11/14/2017
# 1     1  3s1rvMFUweQ    11/14/2017
# 2     2  n1WpP7iowLc    11/14/2017
# 3     3  PUTEiSjKwJU    11/14/2017
# 4     4  rHwDegptbI4    11/14/2017
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id      publish_time  \
# 0                  John Lewis         26.0   11/10/2017 7:38
# 1         Saturday Night Live         24.0   11/12/2017 6:24
# 2                  EminemVEVO         10.0  11/10/2017 17:00
# 3  Salford City Football Club         17.0   11/13/2017 2:30
# 4            Cute Girl Videos         25.0   11/13/2017 1:45
#
# ...

# %%
# Check how many rows have null values
yt_gb_new_DF.isnull().sum()
# Out:
# index                       3
# video_id                  322
# trending_date             322
# title                     322
# channel_title             322
# category_id               322
# publish_time              322
# tags                      322
# views                     322
# likes                     322
# dislikes                  322
# comment_count             322
# thumbnail_link            322
# country                   506
# comments_disabled         322
# ratings_disabled          322
# video_error_or_removed    322
# description               934
# dtype: int64

# %%
# Only keep rows where there is a valid video_id

yt_gb_new_DF = yt_gb_new_DF[yt_gb_new_DF['video_id'].notna()]
yt_gb_new_DF.isnull().sum()
# Out:
# index                       0
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# country                   500
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               612
# dtype: int64

# %%
# Change data type of trending_date column

yt_gb_new_DF['trending_date'] = yt_gb_new_DF['trending_date'].astype('datetime64[ns]')
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
# Create new column for last day trending video appears in dataset
yt_gb_new_DF['max_date'] = yt_gb_new_DF.groupby('video_id').trending_date.transform('max')
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id      publish_time  \
# ...

# %%
# Create new column for first day trending video appears in dataset

yt_gb_new_DF['min_date'] = yt_gb_new_DF.groupby('video_id').trending_date.transform('min')
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
yt_gb_new_DF.dtypes
# Out:
# index                             object
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                      float64
# publish_time                      object
# tags                              object
# views                            float64
# likes                            float64
# dislikes                         float64
# comment_count                    float64
# thumbnail_link                    object
# country                           object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# description                       object
# max_date                  datetime64[ns]
# min_date                  datetime64[ns]
# dtype: object

# %%
# Create new column for how many days video appears in trending dataset

yt_gb_new_DF['days_trending'] = yt_gb_new_DF["max_date"] - yt_gb_new_DF["min_date"]
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
# Change datatype of days_trending column to string

yt_gb_new_DF['days_trending'] = yt_gb_new_DF['days_trending'].astype('str')
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
# Change days_trending column to integer

yt_gb_new_DF['days_trending'] = yt_gb_new_DF['days_trending'].str.rstrip(' days 00:00:00.000000000')
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
yt_gb_new_DF['days_trending'] = yt_gb_new_DF['days_trending'].str.strip()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yt_gb_new_DF['days_trending'].unique()
# Out:
# array(['13', '3', '', '212', '12', '11', '1', '9', '2', '4', '8', '6',
#        '7', '5', '14', '15', '17', '16', '18', '19', '24', '23', '21',
#        '22', '26', '25', '28', '29', '27', '32', '34', '31', '33', '37',
#        '35', '36'], dtype=object)

# %%
yt_gb_new_DF.isnull().sum()
# Out:
# index                       0
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# country                   500
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               612
# max_date                    0
# min_date                    0
# days_trending               0
# dtype: int64

# %%
yt_gb_new_DF['days_trending'] = yt_gb_new_DF['days_trending'].str.replace('', '0')
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yt_gb_new_DF['days_trending'] = '0' + yt_gb_new_DF['days_trending'].astype(str)
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yt_gb_new_DF['days_trending'].unique()
# Out:
# array(['001030', '0030', '00', '00201020', '001020', '001010', '0010',
#        '0090', '0020', '0040', '0080', '0060', '0070', '0050', '001040',
#        '001050', '001070', '001060', '001080', '001090', '002040',
#        '002030', '002010', '002020', '002060', '002050', '002080',
#        '002090', '002070', '003020', '003040', '003010', '003030',
#        '003070', '003050', '003060'], dtype=object)

# %%
yt_gb_new_DF['days_trending'] = yt_gb_new_DF['days_trending'].astype('int') +1
yt_gb_new_DF['days_trending']
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0          1031
# 1            31
# 2          1031
# 3          1031
# 4             1
#           ...
# 39233      3051
# 39234      3031
# 39235      3061
# 39236    201021
# 39237      3031
# Name: days_trending, Length: 38916, dtype: int32

# %%
# Get max views for rows that are latest date

yt_gb_new_DF["max_views"] = yt_gb_new_DF.query('trending_date==max_date')['views']                                           
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
# Get min views for rows that are the earliest date

yt_gb_new_DF["min_views"] = yt_gb_new_DF.query('trending_date==min_date')['views']                                           
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# 2     2  n1WpP7iowLc    2017-11-14
# 3     3  PUTEiSjKwJU    2017-11-14
# 4     4  rHwDegptbI4    2017-11-14
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# ...

# %%
# Get max likes & min likes for rows that are latest and earliest date

yt_gb_new_DF["max_likes"] = yt_gb_new_DF.query('trending_date==max_date')['likes']
yt_gb_new_DF["min_likes"] = yt_gb_new_DF.query('trending_date==min_date')['likes']        
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# ...

# %%
# Get max dislikes and min dislikes for rows that are latest and earliest date

yt_gb_new_DF["max_dislikes"] = yt_gb_new_DF.query('trending_date==max_date')['dislikes']
yt_gb_new_DF["min_dislikes"] = yt_gb_new_DF.query('trending_date==min_date')['dislikes']        
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# ...

# %%
# Get max dislikes and min dislikes for rows that are latest and earliest date

yt_gb_new_DF["max_comments"] = yt_gb_new_DF.query('trending_date==max_date')['comment_count']
yt_gb_new_DF["min_comments"] = yt_gb_new_DF.query('trending_date==min_date')['comment_count']        
yt_gb_new_DF.head()
# Out:
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\samir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#   index     video_id trending_date  \
# 0     0  Jw1Y-zhQURU    2017-11-14
# 1     1  3s1rvMFUweQ    2017-11-14
# ...

# %%
yt_gb_new_DF.dtypes
# Out:
# index                             object
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                      float64
# publish_time                      object
# tags                              object
# views                            float64
# likes                            float64
# dislikes                         float64
# comment_count                    float64
# thumbnail_link                    object
# country                           object
# comments_disabled                 object
# ratings_disabled                  object
# video_error_or_removed            object
# description                       object
# max_date                  datetime64[ns]
# min_date                  datetime64[ns]
# days_trending                      int32
# max_views                        float64
# min_views                        float64
# ...

# %%
yt_gb_new_DF.to_csv('CleanData_GB.csv', index=False, header=True)
